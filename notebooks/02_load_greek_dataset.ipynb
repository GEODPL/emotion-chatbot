# %%
from datasets import load_dataset

# Προσπαθούμε να φορτώσουμε το dataset
try:
    dataset = load_dataset("kostasGRG/greek-twitter-multimodal-dataset")
    print("Dataset loaded successfully!")
    print(dataset)

except Exception as e:
    print("⚠️ Σφάλμα κατά τη φόρτωση του dataset:")
    print(e)
